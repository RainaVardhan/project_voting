# %% [markdown]
# <a href="https://colab.research.google.com/github/RainaVardhan/project_voting/blob/main/demographic_data_cleaned.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/RainaVardhan/project_voting.git
# Out:
# fatal: destination path 'project_voting' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/project_voting/data/county_data/0002_ds250_20205_county_M.csv', encoding='ISO-8859-1') #asked chat how to fix encoding error
df.head()
# Out:
#                GISJOIN            YEAR                     STUSAB  \
# 0  GIS Join Match Code  Data File Year  State Postal Abbreviation
# 1             G0100010       2016-2020                         AL
# 2             G0100030       2016-2020                         AL
# 3             G0100050       2016-2020                         AL
# 4             G0100070       2016-2020                         AL
#
#        REGIONA      DIVISIONA       STATE      STATEA          COUNTY  \
# 0  Region Code  Division Code  State Name  State Code     County Name
# 1          NaN            NaN     Alabama          01  Autauga County
# 2          NaN            NaN     Alabama          01  Baldwin County
# 3          NaN            NaN     Alabama          01  Barbour County
# 4          NaN            NaN     Alabama          01     Bibb County
#
#        COUNTYA                  COUSUBA  ...                AM8FM031  \
# 0  County Code  County Subdivision Code  ...  Female: 35 to 64 years
# 1          001                      NaN  ...                     165
# 2          003                      NaN  ...                     178
# 3          005                      NaN  ...                      89
# 4          007                      NaN  ...                     127
#
#                                     AM8FM032  \
# 0  Female: 35 to 64 years: With a disability
# 1                                        347
# 2                                        625
# 3                                        154
# 4                                        172
#
#                                 AM8FM033                AM8FM034  \
# 0  Female: 35 to 64 years: No disability  Female: 65 to 74 years
# 1                                    373                      84
# 2                                    604                     113
# 3                                    182                       2
# 4                                    198                     125
#
#                                     AM8FM035  \
# 0  Female: 65 to 74 years: With a disability
# 1                                        164
# 2                                        443
# 3                                         87
# 4                                        144
#
#                                 AM8FM036                   AM8FM037  \
# 0  Female: 65 to 74 years: No disability  Female: 75 years and over
# 1                                    140                        130
# 2                                    448                        154
# 3                                     87                         41
# 4                                    159                        149
#
#                                        AM8FM038  \
# 0  Female: 75 years and over: With a disability
# 1                                           184
# 2                                           475
# 3                                            99
# 4                                           160
#
#                                    AM8FM039    AM9SM001
# 0  Female: 75 years and over: No disability  Gini Index
# 1                                       178      0.0326
# 2                                       436      0.0119
# 3                                        99      0.0252
# 4                                       147      0.0408
#
# [5 rows x 161 columns]

# %%
df = df[df['STATE'] == 'Virginia']
df.head()
# Out:
#        GISJOIN       YEAR STUSAB REGIONA DIVISIONA     STATE STATEA  \
# 2822  G5100010  2016-2020     VA     NaN       NaN  Virginia     51
# 2823  G5100030  2016-2020     VA     NaN       NaN  Virginia     51
# 2824  G5100050  2016-2020     VA     NaN       NaN  Virginia     51
# 2825  G5100070  2016-2020     VA     NaN       NaN  Virginia     51
# 2826  G5100090  2016-2020     VA     NaN       NaN  Virginia     51
#
#                 COUNTY COUNTYA COUSUBA  ... AM8FM031 AM8FM032 AM8FM033  \
# 2822   Accomack County     001     NaN  ...      144      178      232
# 2823  Albemarle County     003     NaN  ...       90      235      249
# 2824  Alleghany County     005     NaN  ...       73      131      153
# 2825     Amelia County     007     NaN  ...       94      162      187
# 2826    Amherst County     009     NaN  ...      115      169      180
#
#      AM8FM034 AM8FM035 AM8FM036 AM8FM037 AM8FM038 AM8FM039 AM9SM001
# 2822      107      138      172       35      146      147   0.0194
# 2823       79      177      183      159      343      325   0.0150
# 2824       65      125      126       60      115      101   0.0287
# 2825       18       86       87       48       92       87   0.0416
# 2826       31      147      148       72      133      151   0.0211
#
# [5 rows x 161 columns]

# %%
df.columns
# Out:
# Index(['GISJOIN', 'YEAR', 'STUSAB', 'REGIONA', 'DIVISIONA', 'STATE', 'STATEA',
#        'COUNTY', 'COUNTYA', 'COUSUBA',
#        ...
#        'AM8FM031', 'AM8FM032', 'AM8FM033', 'AM8FM034', 'AM8FM035', 'AM8FM036',
#        'AM8FM037', 'AM8FM038', 'AM8FM039', 'AM9SM001'],
#       dtype='object', length=161)

# %%
df['U.S. citizen: Born in the US'] = df['AM0KM002']
df['U.S. citizen: Born abroad'] = df['AM0KM004']
df['U.S. citizen: Naturalized'] = df['AM0KM005']
df['Male'] = df['AM8FM002']
df['Female'] = df['AM8FM021']
df['18 to 30 years'] = df['AM8FM009']+df['AM8FM028']
df['35 to 64 years'] = df['AM8FM012']+df['AM8FM031']
df['65 to 74 years'] = df['AM8FM015']+df['AM8FM034']
df['75 years and over'] = df['AM8FM018']+df['AM8FM037']

# %%
vars_to_keep = ['COUNTY','U.S. citizen: Born in the US', 'U.S. citizen: Born abroad', 'U.S. citizen: Naturalized', 'Male', 'Female', '18 to 30 years', '35 to 64 years', '65 to 74 years', '75 years and over']
county_data = df[vars_to_keep]
county_data.head()
# Out:
#                 COUNTY U.S. citizen: Born in the US U.S. citizen: Born abroad  \
# 2822   Accomack County                          541                       113
# 2823  Albemarle County                          936                       299
# 2824  Alleghany County                          121                        96
# 2825     Amelia County                          142                       122
# 2826    Amherst County                          190                        77
#
#      U.S. citizen: Naturalized Male Female 18 to 30 years 35 to 64 years  \
# 2822                       295  244    222         117115         136144
# 2823                       626  193    166          16785          12690
# 2824                        45  137    112           6241           8473
# 2825                       105  131    135          14879          18494
# 2826                       132  154    169          83105          97115
#
#      65 to 74 years 75 years and over
# 2822          54107              6535
# 2823           9079             80159
# 2824           5165              3160
# 2825           8118              8348
# 2826           2131              4672

# %%
county_data.isna().sum()
# Out:
# COUNTY                          0
# U.S. citizen: Born in the US    0
# U.S. citizen: Born abroad       0
# U.S. citizen: Naturalized       0
# Male                            0
# Female                          0
# 18 to 30 years                  0
# 35 to 64 years                  0
# 65 to 74 years                  0
# 75 years and over               0
# dtype: int64

# %%
print(county_data.head())
print(county_data.shape)
county_val=county_data['COUNTY']
# Out:
#                 COUNTY U.S. citizen: Born in the US U.S. citizen: Born abroad  \
# 2822   Accomack County                          541                       113
# 2823  Albemarle County                          936                       299
# 2824  Alleghany County                          121                        96
# 2825     Amelia County                          142                       122
# 2826    Amherst County                          190                        77
#
#      U.S. citizen: Naturalized Male Female 18 to 30 years 35 to 64 years  \
# 2822                       295  244    222         117115         136144
# 2823                       626  193    166          16785          12690
# 2824                        45  137    112           6241           8473
# 2825                       105  131    135          14879          18494
# 2826                       132  154    169          83105          97115
#
#      65 to 74 years 75 years and over
# 2822          54107              6535
# 2823           9079             80159
# 2824           5165              3160
# 2825           8118              8348
# 2826           2131              4672
# (133, 10)

# %%
county_data.to_csv('file.csv', index=False)
